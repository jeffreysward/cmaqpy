# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from cmaqpy import prepemis

# %%
# Read in the generator data previously preprocessed by ERTAC EGU tool
base_df = pd.read_csv('test_calc_hourly_base.csv', low_memory=False)
# Change op_hour to str
base_df = base_df.astype({'op_hour': 'str'})
# Change the orispl_code to a string
base_df = base_df.astype({'orispl_code': 'int'})
base_df = base_df.astype({'orispl_code': 'str'})
# Pad the string for formatting
base_df['op_hour'] = base_df['op_hour'].str.zfill(2)
# Add a datetime column 
base_df['datetime'] = pd.to_datetime(base_df['op_date'] + ' ' + base_df['op_hour'])
# Add the datetime as an additional index
base_df = base_df.set_index(['datetime'], append=True)
base_df.head()
# Out:
#                       ertac_region ertac_fuel_unit_type_bin state  \
#   datetime
# 0 2016-01-01 00:00:00         SRSE               Boiler Gas    AL
# 1 2016-01-01 01:00:00         SRSE               Boiler Gas    AL
# 2 2016-01-01 02:00:00         SRSE               Boiler Gas    AL
# 3 2016-01-01 03:00:00         SRSE               Boiler Gas    AL
# 4 2016-01-01 04:00:00         SRSE               Boiler Gas    AL
#
#                       facility_name orispl_code unitid     op_date op_hour  \
#   datetime
# 0 2016-01-01 00:00:00         Barry           3      1  2016-01-01      00
# 1 2016-01-01 01:00:00         Barry           3      1  2016-01-01      01
# 2 2016-01-01 02:00:00         Barry           3      1  2016-01-01      02
# 3 2016-01-01 03:00:00         Barry           3      1  2016-01-01      03
# 4 2016-01-01 04:00:00         Barry           3      1  2016-01-01      04
#
#                        op_time  gload (MW-hr)  ...  so2_rate_measure_flg  \
#   datetime                                     ...
# 0 2016-01-01 00:00:00      0.0            NaN  ...                   NaN
# 1 2016-01-01 01:00:00      0.0            NaN  ...                   NaN
# 2 2016-01-01 02:00:00      0.0            NaN  ...                   NaN
# 3 2016-01-01 03:00:00      0.0            NaN  ...                   NaN
# 4 2016-01-01 04:00:00      0.0            NaN  ...                   NaN
#
#                        nox_rate (lbs/mmBtu) nox_rate_measure_flg  \
#   datetime
# 0 2016-01-01 00:00:00                   NaN                  NaN
# 1 2016-01-01 01:00:00                   NaN                  NaN
# 2 2016-01-01 02:00:00                   NaN                  NaN
# 3 2016-01-01 03:00:00                   NaN                  NaN
# 4 2016-01-01 04:00:00                   NaN                  NaN
#
#                        nox_mass (lbs) nox_mass_measure_flg  co2_mass (tons)  \
#   datetime
# 0 2016-01-01 00:00:00             NaN                  NaN              NaN
# 1 2016-01-01 01:00:00             NaN                  NaN              NaN
# 2 2016-01-01 02:00:00             NaN                  NaN              NaN
# 3 2016-01-01 03:00:00             NaN                  NaN              NaN
# 4 2016-01-01 04:00:00             NaN                  NaN              NaN
#
#                       co2_mass_measure_flg  co2_rate (tons/mmBtu)  \
#   datetime
# 0 2016-01-01 00:00:00                  NaN                    NaN
# 1 2016-01-01 01:00:00                  NaN                    NaN
# 2 2016-01-01 02:00:00                  NaN                    NaN
# 3 2016-01-01 03:00:00                  NaN                    NaN
# 4 2016-01-01 04:00:00                  NaN                    NaN
#
#                       co2_rate_measure_flg  heat_input (mmBtu)
#   datetime
# 0 2016-01-01 00:00:00                  NaN                 NaN
# 1 2016-01-01 01:00:00                  NaN                 NaN
# 2 2016-01-01 02:00:00                  NaN                 NaN
# 3 2016-01-01 03:00:00                  NaN                 NaN
# 4 2016-01-01 04:00:00                  NaN                 NaN
#
# [5 rows x 24 columns]

# %%
# Read in ML CO2 emissions estimations
ml_co2 = prepemis.fmt_like_camd(data_file='../ny_emis/ml_output/pred_xg_co2.csv', lu_file='../ny_emis/ed_output/RGGI_to_NYISO.csv')

# %%
# Read in ML NOx emissions estimations
ml_nox = prepemis.fmt_like_camd(data_file='../ny_emis/ml_output/pred_xg_nox.csv', lu_file='../ny_emis/ed_output/RGGI_to_NYISO.csv')

# %%
# Read in ML SO2 emissions estimations
ml_so2 = prepemis.fmt_like_camd(data_file='../ny_emis/ml_output/pred_xg_so2.csv', lu_file='../ny_emis/ed_output/RGGI_to_NYISO.csv')

# %%
# Read in NY Simple Net generation
ed_gen = prepemis.fmt_like_camd(data_file='../ny_emis/ed_output/thermal_with_renewable_20160805_20160815.csv', lu_file='../ny_emis/ed_output/RGGI_to_NYISO.csv')

# %% [markdown]
# Now, we want to replace the emissions values that we got from the ML model in the CAMD database. We use the follow steps
# 1. Match units to a ORISPL and UNIT ID (done in prep)
# 2. Check to see how many of the units in the Simple Net are in the CAMD data (some will be too small) (done in prep)
# 3. Add additional rows to the Simple Net data when the NYISO PTID corresponds to multiple UNIT IDs and divide the generation evenly among the units (done in prep)
# 4. Replace the data in `calc_hourly_base.csv`

# %%
idx = 62
midx = pd.IndexSlice
# Get the ORISPL and the Unit ID
egu_orispl = ml_co2.loc[idx].ORISPL
egu_unitid = ml_co2.loc[idx]['Unit ID']
print(f'ORISPL: {egu_orispl}\tUNIT ID:{egu_unitid}')
# Out:
# ORISPL: 2535	UNIT ID:1

# %%
ml_co2.columns[5]
# Out:
# Timestamp('2016-08-05 00:00:00')

# %%
# Extract this ORISPL and UNIT ID from the base DataFrame
egu_df = base_df.loc[(base_df['orispl_code'] == egu_orispl) & (base_df['unitid'] == egu_unitid)]
egu_df.head()
# Out:
#                            ertac_region ertac_fuel_unit_type_bin state  \
#        datetime
# 840959 2016-01-01 00:00:00         NYUP                     Coal    NY
# 840960 2016-01-01 01:00:00         NYUP                     Coal    NY
# 840961 2016-01-01 02:00:00         NYUP                     Coal    NY
# 840962 2016-01-01 03:00:00         NYUP                     Coal    NY
# 840963 2016-01-01 04:00:00         NYUP                     Coal    NY
#
#                                             facility_name orispl_code unitid  \
#        datetime
# 840959 2016-01-01 00:00:00  Cayuga Operating Company, LLC        2535      1
# 840960 2016-01-01 01:00:00  Cayuga Operating Company, LLC        2535      1
# 840961 2016-01-01 02:00:00  Cayuga Operating Company, LLC        2535      1
# 840962 2016-01-01 03:00:00  Cayuga Operating Company, LLC        2535      1
# 840963 2016-01-01 04:00:00  Cayuga Operating Company, LLC        2535      1
#
#                                op_date op_hour  op_time  gload (MW-hr)  ...  \
#        datetime                                                         ...
# 840959 2016-01-01 00:00:00  2016-01-01      00      0.0            NaN  ...
# 840960 2016-01-01 01:00:00  2016-01-01      01      0.0            NaN  ...
# 840961 2016-01-01 02:00:00  2016-01-01      02      0.0            NaN  ...
# 840962 2016-01-01 03:00:00  2016-01-01      03      0.0            NaN  ...
# 840963 2016-01-01 04:00:00  2016-01-01      04      0.0            NaN  ...
#
#                             so2_rate_measure_flg  nox_rate (lbs/mmBtu)  \
#        datetime
# 840959 2016-01-01 00:00:00                   NaN                   NaN
# 840960 2016-01-01 01:00:00                   NaN                   NaN
# 840961 2016-01-01 02:00:00                   NaN                   NaN
# 840962 2016-01-01 03:00:00                   NaN                   NaN
# 840963 2016-01-01 04:00:00                   NaN                   NaN
#
#                            nox_rate_measure_flg  nox_mass (lbs)  \
#        datetime
# 840959 2016-01-01 00:00:00                  NaN             NaN
# 840960 2016-01-01 01:00:00                  NaN             NaN
# 840961 2016-01-01 02:00:00                  NaN             NaN
# 840962 2016-01-01 03:00:00                  NaN             NaN
# 840963 2016-01-01 04:00:00                  NaN             NaN
#
#                            nox_mass_measure_flg  co2_mass (tons)  \
#        datetime
# 840959 2016-01-01 00:00:00                  NaN              NaN
# 840960 2016-01-01 01:00:00                  NaN              NaN
# 840961 2016-01-01 02:00:00                  NaN              NaN
# 840962 2016-01-01 03:00:00                  NaN              NaN
# 840963 2016-01-01 04:00:00                  NaN              NaN
#
#                            co2_mass_measure_flg  co2_rate (tons/mmBtu)  \
#        datetime
# 840959 2016-01-01 00:00:00                  NaN                    NaN
# 840960 2016-01-01 01:00:00                  NaN                    NaN
# 840961 2016-01-01 02:00:00                  NaN                    NaN
# 840962 2016-01-01 03:00:00                  NaN                    NaN
# 840963 2016-01-01 04:00:00                  NaN                    NaN
#
#                            co2_rate_measure_flg  heat_input (mmBtu)
#        datetime
# 840959 2016-01-01 00:00:00                  NaN                 NaN
# 840960 2016-01-01 01:00:00                  NaN                 NaN
# 840961 2016-01-01 02:00:00                  NaN                 NaN
# 840962 2016-01-01 03:00:00                  NaN                 NaN
# 840963 2016-01-01 04:00:00                  NaN                 NaN
#
# [5 rows x 24 columns]

# %%
ml_co2.loc[idx, ml_co2.columns[5:]]
# Out:
# 2016-08-05 00:00:00     51.75686
# 2016-08-05 01:00:00     51.75686
# 2016-08-05 02:00:00     51.75686
# 2016-08-05 03:00:00     51.75686
# 2016-08-05 04:00:00     51.75686
#                          ...
# 2016-08-15 19:00:00    150.41125
# 2016-08-15 20:00:00    150.41125
# 2016-08-15 21:00:00    150.41125
# 2016-08-15 22:00:00    150.41125
# 2016-08-15 23:00:00     51.75686
# Name: 62, Length: 264, dtype: object

# %%
egu_df.loc[midx[:, ml_co2.columns[5:]], 'co2_mass (tons)']
# Out:
#         datetime
# 846167  2016-08-05 00:00:00    154.2
# 846168  2016-08-05 01:00:00    154.4
# 846169  2016-08-05 02:00:00    152.4
# 846170  2016-08-05 03:00:00    151.8
# 846171  2016-08-05 04:00:00    152.0
#                                ...
# 846426  2016-08-15 19:00:00    153.0
# 846427  2016-08-15 20:00:00    152.4
# 846428  2016-08-15 21:00:00    153.1
# 846429  2016-08-15 22:00:00    153.2
# 846430  2016-08-15 23:00:00    152.9
# Name: co2_mass (tons), Length: 264, dtype: float64

# %%
# Replace the CO2 emissions values
# NOTE: this is still a dangerous way of doing this -- would be cool if we didn't need .values method
egu_df.loc[midx[:, ml_co2.columns[5:]], 'co2_mass (tons)'] = ml_co2.loc[idx, ml_co2.columns[5:]].values
# Replace the SO2 emissions values
egu_df.loc[midx[:, ml_so2.columns[5:]], 'so2_mass (lbs)'] = ml_so2.loc[idx, ml_so2.columns[5:]].values
# Replace the NOx emissions values
egu_df.loc[midx[:, ml_nox.columns[5:]], 'nox_mass (lbs)'] = ml_nox.loc[idx, ml_nox.columns[5:]].values
# Replace the load values
egu_df.loc[midx[:, ed_gen.columns[5:]], 'gload (MW-hr)'] = ed_gen.loc[idx, ed_gen.columns[5:]].values
# Combine this new unit data back into the base_df
base_df.update(egu_df)
# Out:
# /home/jas983/anaconda3/envs/oshwind/lib/python3.8/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %% [markdown]
# Check to make sure that the overwrite worked

# %% [markdown]
# Here's the algorithm in a loop

# %%
# Get the name of an individual EGU -- this is how units are identified in the NY Simple Net & the ML
for idx in ml_co2.index:
    # Get the ORISPL and the Unit ID
    egu_orispl = ml_co2.loc[idx].ORISPL
    egu_unitid = ml_co2.loc[idx]['Unit ID']
    print(f'Working on ORISPL: {egu_orispl}\tUNIT ID:{egu_unitid}')

    # Extract this ORISPL and UNIT ID from the base DataFrame
    egu_df = base_df.loc[(base_df['orispl_code'] == egu_orispl) & (base_df['unitid'] == egu_unitid)]
    # Extract the correct time window
    if len(egu_df) == 0:
        print('Warning: this unit was not found in the CAMD data... skipping')
    else:
        # Replace the CO2 emissions values
        # NOTE: this is probably a dangerous way of doing this -- might be better to add the datetime as another index in the egu_df
        egu_df.loc[midx[:, ml_co2.columns[5:]], 'co2_mass (tons)'] = ml_co2.loc[idx, ml_co2.columns[5:]].values
        # Replace the SO2 emissions values
        egu_df.loc[midx[:, ml_so2.columns[5:]], 'so2_mass (lbs)'] = ml_so2.loc[idx, ml_so2.columns[5:]].values
        # Replace the NOx emissions values
        egu_df.loc[midx[:, ml_nox.columns[5:]], 'nox_mass (lbs)'] = ml_nox.loc[idx, ml_nox.columns[5:]].values
        # Replace the load values
        egu_df.loc[midx[:, ed_gen.columns[5:]], 'gload (MW-hr)'] = ed_gen.loc[idx, ed_gen.columns[5:]].values
        # Combine this new unit data back into the base_df
        base_df.update(egu_df)
# Out:
# Working on ORISPL: 7910	UNIT ID:2301
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 7910	UNIT ID:2302
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 10619	UNIT ID:1
# /home/jas983/anaconda3/envs/oshwind/lib/python3.8/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# Working on ORISPL: 2490	UNIT ID:20
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2490	UNIT ID:30
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55375	UNIT ID:CT1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55375	UNIT ID:CT2
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55375	UNIT ID:CT3
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55375	UNIT ID:CT4
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT2-1A
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT2-1B
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT2-2A
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT2-2B
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT2-3A
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT2-3B
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT2-4A
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT2-4B
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT3-1A
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT3-1B
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT3-2A
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT3-2B
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT3-3A
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT3-3B
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT3-4A
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT3-4B
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT4-1A
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT4-1B
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT4-2A
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT4-2B
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT4-3A
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT4-3B
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT4-4A
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55243	UNIT ID:CT4-4B
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8906	UNIT ID:20
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8906	UNIT ID:31RH
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8906	UNIT ID:32SH
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8906	UNIT ID:51RH
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8906	UNIT ID:52SH
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55405	UNIT ID:1
# Working on ORISPL: 55405	UNIT ID:2
# Working on ORISPL: 55405	UNIT ID:3
# Working on ORISPL: 54593	UNIT ID:1
# Working on ORISPL: 55699	UNIT ID:1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55699	UNIT ID:2
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 10617	UNIT ID:1
# Working on ORISPL: 2539	UNIT ID:10001
# Working on ORISPL: 2539	UNIT ID:10002
# Working on ORISPL: 2539	UNIT ID:10003
# Working on ORISPL: 50292	UNIT ID:GT1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 50292	UNIT ID:GT2
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 50292	UNIT ID:GT3
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 50292	UNIT ID:GT4
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2625	UNIT ID:1
# Working on ORISPL: 2625	UNIT ID:2
# Working on ORISPL: 7912	UNIT ID:BW01
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 54914	UNIT ID:1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 54914	UNIT ID:2
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 56234	UNIT ID:1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 50978	UNIT ID:A
# Working on ORISPL: 50978	UNIT ID:B
# Working on ORISPL: 10620	UNIT ID:1
# Working on ORISPL: 10190	UNIT ID:1
# Working on ORISPL: 2535	UNIT ID:1
# Working on ORISPL: 2480	UNIT ID:1
# Working on ORISPL: 2480	UNIT ID:2
# Working on ORISPL: 2480	UNIT ID:3
# Working on ORISPL: 2480	UNIT ID:4
# Working on ORISPL: 2511	UNIT ID:10
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2511	UNIT ID:20
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2511	UNIT ID:U00012
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2511	UNIT ID:U00013
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2511	UNIT ID:U00014
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2511	UNIT ID:U00015
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2511	UNIT ID:U00016
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2511	UNIT ID:U00017
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2511	UNIT ID:U00019
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2511	UNIT ID:nan
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2511	UNIT ID:nan
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2511	UNIT ID:nan
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2511	UNIT ID:nan
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2493	UNIT ID:1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2493	UNIT ID:2
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55786	UNIT ID:CT01
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55786	UNIT ID:CT02
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 56259	UNIT ID:CT-1
# Working on ORISPL: 56259	UNIT ID:CT-2
# Working on ORISPL: 56032	UNIT ID:1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 54131	UNIT ID:NTCT1
# Working on ORISPL: 2679	UNIT ID:5
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2514	UNIT ID:U00020
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2514	UNIT ID:U00021
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 7869	UNIT ID:UGT012
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 7869	UNIT ID:UGT013
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT01-1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT01-2
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT01-3
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT01-4
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT01-5
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT01-6
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT01-7
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT02-1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT02-2
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT02-3
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT02-4
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT02-5
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT02-6
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT02-7
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT02-8
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT03-1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT03-2
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT03-3
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT03-4
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT03-5
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT03-6
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT03-7
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT03-8
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT04-1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT04-2
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT04-3
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT04-4
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT04-5
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT04-6
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2494	UNIT ID:CT04-8
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT01-1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT01-2
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT01-3
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT01-4
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT01-5
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT01-6
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT01-7
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT01-8
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT02-1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT02-2
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT02-3
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT02-4
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT02-5
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT02-6
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT02-7
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2499	UNIT ID:CT02-8
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2527	UNIT ID:6
# Working on ORISPL: 7914	UNIT ID:HR01
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 7914	UNIT ID:HR02
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55969	UNIT ID:U-01
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 7913	UNIT ID:HG01
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 7913	UNIT ID:HG02
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2628	UNIT ID:1
# Working on ORISPL: 8007	UNIT ID:U00001
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8007	UNIT ID:U00002
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8007	UNIT ID:U00003
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8007	UNIT ID:U00004
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8007	UNIT ID:U00005
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8007	UNIT ID:U00006
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8007	UNIT ID:U00007
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8007	UNIT ID:U00008
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8007	UNIT ID:U00009
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8007	UNIT ID:U00010
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2496	UNIT ID:CT0003
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2496	UNIT ID:CT0004
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2496	UNIT ID:CT0005
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 50458	UNIT ID:1
# Working on ORISPL: 54076	UNIT ID:1
# Working on ORISPL: 50450	UNIT ID:1
# Working on ORISPL: 50449	UNIT ID:1
# Working on ORISPL: 50451	UNIT ID:1
# Working on ORISPL: 54547	UNIT ID:1
# Working on ORISPL: 54547	UNIT ID:2
# Working on ORISPL: 54547	UNIT ID:3
# Working on ORISPL: 54547	UNIT ID:4
# Working on ORISPL: 54114	UNIT ID:GT1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 54114	UNIT ID:GT2
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 54041	UNIT ID:11854
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 54041	UNIT ID:11855
# Working on ORISPL: 54041	UNIT ID:11856
# Working on ORISPL: 54592	UNIT ID:1
# Working on ORISPL: 52056	UNIT ID:4
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 54149	UNIT ID:1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 7915	UNIT ID:NO1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2516	UNIT ID:1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2516	UNIT ID:2
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2516	UNIT ID:3
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2516	UNIT ID:4
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2594	UNIT ID:5
# Working on ORISPL: 2594	UNIT ID:6
# Working on ORISPL: 56188	UNIT ID:1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 56196	UNIT ID:CTG7A
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 56196	UNIT ID:CTG7B
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2517	UNIT ID:3
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2517	UNIT ID:4
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2517	UNIT ID:UGT002
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2517	UNIT ID:UGT003
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8053	UNIT ID:PT01
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2500	UNIT ID:10
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2500	UNIT ID:20
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2500	UNIT ID:30
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2500	UNIT ID:UCC001
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 54034	UNIT ID:1GTDBS
# Working on ORISPL: 7314	UNIT ID:1GTDBS
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 8006	UNIT ID:1
# Working on ORISPL: 8006	UNIT ID:2
# Working on ORISPL: 2682	UNIT ID:9
# Working on ORISPL: 2682	UNIT ID:10
# Working on ORISPL: 2682	UNIT ID:20
# Working on ORISPL: 54574	UNIT ID:1
# Working on ORISPL: 54574	UNIT ID:2
# Working on ORISPL: 10725	UNIT ID:CTG101
# Working on ORISPL: 10725	UNIT ID:CTG201
# Working on ORISPL: 10725	UNIT ID:CTG301
# Working on ORISPL: 2632	UNIT ID:1
# Working on ORISPL: 55787	UNIT ID:CT01
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 55787	UNIT ID:CT02
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 6082	UNIT ID:1
# Working on ORISPL: 50744	UNIT ID:1GTDBS
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 10621	UNIT ID:1
# Working on ORISPL: 56940	UNIT ID:1
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 56940	UNIT ID:2
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 7909	UNIT ID:VB01
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 7909	UNIT ID:VB02
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 7146	UNIT ID:UGT007
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 7146	UNIT ID:UGT008
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 7146	UNIT ID:UGT009
# Warning: this unit was not found in the CAMD data... skipping
# Working on ORISPL: 2521	UNIT ID:UGT001
# Warning: this unit was not found in the CAMD data... skipping

# %%
base_df.head()
# Out:
#                       ertac_region ertac_fuel_unit_type_bin state  \
#   datetime
# 0 2016-01-01 00:00:00         SRSE               Boiler Gas    AL
# 1 2016-01-01 01:00:00         SRSE               Boiler Gas    AL
# 2 2016-01-01 02:00:00         SRSE               Boiler Gas    AL
# 3 2016-01-01 03:00:00         SRSE               Boiler Gas    AL
# 4 2016-01-01 04:00:00         SRSE               Boiler Gas    AL
#
#                       facility_name orispl_code unitid     op_date op_hour  \
#   datetime
# 0 2016-01-01 00:00:00         Barry           3      1  2016-01-01      00
# 1 2016-01-01 01:00:00         Barry           3      1  2016-01-01      01
# 2 2016-01-01 02:00:00         Barry           3      1  2016-01-01      02
# 3 2016-01-01 03:00:00         Barry           3      1  2016-01-01      03
# 4 2016-01-01 04:00:00         Barry           3      1  2016-01-01      04
#
#                        op_time gload (MW-hr)  ...  so2_rate_measure_flg  \
#   datetime                                    ...
# 0 2016-01-01 00:00:00      0.0           NaN  ...                   NaN
# 1 2016-01-01 01:00:00      0.0           NaN  ...                   NaN
# 2 2016-01-01 02:00:00      0.0           NaN  ...                   NaN
# 3 2016-01-01 03:00:00      0.0           NaN  ...                   NaN
# 4 2016-01-01 04:00:00      0.0           NaN  ...                   NaN
#
#                       nox_rate (lbs/mmBtu) nox_rate_measure_flg  \
#   datetime
# 0 2016-01-01 00:00:00                  NaN                  NaN
# 1 2016-01-01 01:00:00                  NaN                  NaN
# 2 2016-01-01 02:00:00                  NaN                  NaN
# 3 2016-01-01 03:00:00                  NaN                  NaN
# 4 2016-01-01 04:00:00                  NaN                  NaN
#
#                        nox_mass (lbs) nox_mass_measure_flg  co2_mass (tons)  \
#   datetime
# 0 2016-01-01 00:00:00             NaN                  NaN              NaN
# 1 2016-01-01 01:00:00             NaN                  NaN              NaN
# 2 2016-01-01 02:00:00             NaN                  NaN              NaN
# 3 2016-01-01 03:00:00             NaN                  NaN              NaN
# 4 2016-01-01 04:00:00             NaN                  NaN              NaN
#
#                       co2_mass_measure_flg co2_rate (tons/mmBtu)  \
#   datetime
# 0 2016-01-01 00:00:00                  NaN                   NaN
# 1 2016-01-01 01:00:00                  NaN                   NaN
# 2 2016-01-01 02:00:00                  NaN                   NaN
# 3 2016-01-01 03:00:00                  NaN                   NaN
# 4 2016-01-01 04:00:00                  NaN                   NaN
#
#                       co2_rate_measure_flg heat_input (mmBtu)
#   datetime
# 0 2016-01-01 00:00:00                  NaN                NaN
# 1 2016-01-01 01:00:00                  NaN                NaN
# 2 2016-01-01 02:00:00                  NaN                NaN
# 3 2016-01-01 03:00:00                  NaN                NaN
# 4 2016-01-01 04:00:00                  NaN                NaN
#
# [5 rows x 24 columns]

# %%
# Save the updated dataset to a new CSV
base_df = base_df.drop(columns=['datetime'])
base_df.to_csv('updated_test_calc_hourly_base.csv', index=False)

# %%
# Now, test the prepemis.update_camd() function
in_emis_file = 'test_calc_hourly_base.csv'
co2_file = '../ny_emis/ml_output/pred_xg_co2.csv'
nox_file = '../ny_emis/ml_output/pred_xg_nox.csv'
so2_file = '../ny_emis/ml_output/pred_xg_so2.csv'
gen_file = '../ny_emis/ed_output/thermal_with_renewable_20160805_20160815.csv'
lu_file = '../ny_emis/ed_output/RGGI_to_NYISO.csv'
out_emis_file = 'updated_test_calc_hourly_base_v2.csv'

prepemis.update_camd(in_emis_file=in_emis_file, co2_file=co2_file, 
                     nox_file=nox_file, so2_file=so2_file, 
                     gen_file=gen_file, lu_file=lu_file, 
                     out_emis_file=out_emis_file)
