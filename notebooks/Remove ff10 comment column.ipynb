# %% [markdown]
# I've recieved an `ERROR: Overflow prevented while parsing line PARSLINE` while running SMOKE and it could be that some of the comments are too long. Therefore, I'm going to try deleting the comment column (or replacing it with an empty column).
#
# *DISCLAIMER: This doesn't currently work*

# %%
import pandas as pd
import numpy as np
import csv

# %%
# Read in the ff10 csv file
folder = '/share/mzhang/jas983/emissions_data/nei_platform2016/v1/2016fh_16j/inputs/ptertac/'
f = 'CONUS2016_S0_fs_ff10_future.csv'
f_hrly = 'CONUS2016_S0_fs_ff10_hourly_future.csv'
df_f = pd.read_csv(f'{folder}{f}', header=8)
df_f_hrly = pd.read_csv(f'{folder}{f_hrly}', header=8)
# df_f.tail()
# Out:
# /home/jas983/anaconda3/envs/oshwind/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (3,4,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-30-b6f32bcc4759> in <module>
#       4 f_hrly = 'CONUS2016_S0_fs_ff10_hourly_future.csv'
#       5 df_f = pd.read_csv(f'{folder}{f}', header=8)
# ----> 6 df_f_hrly = pd.read_csv(f'{folder}{f_hrly}', header=8)
#       7 # df_f.tail()
#
# ...

# %%
# Change the comments to NaN
df_f.comment = np.nan
df_f_hrly.comment = np.nan
df_f.tail()
# Out:
#       country_cd  region_cd  tribal_code facility_id    unit_id  rel_point_id  \
# 77458         US      56021          NaN    17307411  120645013     122737612
# 77459         US      56021          NaN    17307411  120645013     122737612
# 77460         US      56021          NaN    17307411  120645013     122737612
# 77461         US      56021          NaN    17307411  120645013     122737612
# 77462         US      56021          NaN    17307411  120645013     122737612
#
#       process_id agy_facility_id agy_unit_id agy_rel_point_id  ... apr_pctred  \
# 77458  172272514           24912       11084           VER003  ...        NaN
# 77459  172272514           24912       11084           VER003  ...        NaN
# 77460  172272514           24912       11084           VER003  ...        NaN
# 77461  172272514           24912       11084           VER003  ...        NaN
# 77462  172272514           24912       11084           VER003  ...        NaN
#
# ...

# %%
df_f.to_csv(f'{folder}CONUS2016_S0_fs_ff10_future_nc.csv', index=False)
df_f_hrly.to_csv(f'{folder}CONUS2016_S0_fs_ff10_hourly_future_nc.csv', index=False)
