# %% [markdown]
# In order to match files from our modeling work to those in the AMPD database we are working with several different names and IDs. This notebook goes through my consistency checks for these files.

# %%
import pandas as pd
import numpy as np

# %%
# Read in the lookup table where the RGGI to NYISO IDs are kept
lu_df = pd.read_csv('../ny_emis/ed_output/RGGI_to_NYISO.csv', header=1)
lu_df = lu_df.drop(columns=['Notes', 'Unnamed: 6'])
lu_df.head()
# Out:
#          RGGI Facility Name  ORISPL Unit ID NYISO Name       PTID
# 0               23rd & 3rd     7910    2301  Gowanus 5      24156
# 1               23rd & 3rd     7910    2302  Gowanus 6      24157
# 2                 AG-Energy   10803       1        NaN  999999999
# 3                 AG-Energy   10803       2        NaN  999999999
# 4  Allegany Station No. 133   10619       1   Allegany      23514

# %%
# Read in the generator info
ed_gen_info = pd.read_csv('../ny_emis/ed_output/genInfo.csv')
ed_gen_info.head()
# Out:
#           NYISOName   PTID Zone        UnitType     FuelType  Latitude  \
# 0          Allegany  23514    B  Combined Cycle  Natural Gas   42.5083
# 1  Arthur Kill ST 2  23512    J   Steam Turbine  Natural Gas   40.5915
# 2  Arthur Kill ST 3  23513    J   Steam Turbine  Natural Gas   40.5915
# 3         Astoria 2  24149    J   Steam Turbine  Natural Gas   40.7869
# 4         Astoria 3  23516    J   Steam Turbine   Fuel Oil 2   40.7869
#
#    Longitude  maxPower  minPower  maxRampAgc  maxRamp10  maxRamp30  maxRamp60  \
# 0   -78.0661      66.0      11.0    0.733333   7.333333      22.00       44.0
# 1   -74.2027     349.0      96.0    2.850000  28.500000      85.50      171.0
# 2   -74.2027     539.0       1.0    3.108333  31.083333      93.25      186.5
# 3   -73.9122     153.0       1.0    0.808333   8.083333      24.25       48.5
# 4   -73.9122     756.0      40.0    6.033333  60.333333     181.00      362.0
#
#    HeatRateLM_R2  HeatRateQM_R2  BusName  NCOST     cost_1       cost_0
# 0       0.862443       0.891407       62      1  22.682017   -40.234372
# 1       0.995837       0.995860       82      1  25.306225   736.980064
# 2       0.986235       0.991460       82      1  25.957282   993.894899
# 3       0.987563       0.988910       82      1  31.302863   430.832898
# 4       0.996075       0.996269       82      1  66.084194  3680.943877

# %%
# Check to see if all the generators in the NYSN are in the lookup DataFrame
for name in ed_gen_info.NYISOName:
    exists = sum(lu_df['NYISO Name'] == name)
    if exists == 1:
        print(f'{name}:\t\t\tfound')
    elif exists == 0:
        print(f'{name}:\t\t\tmissing')
    elif exists > 1:
        print(f'{name}:\t\t\thas multiple entries')
    else:
        print(f'{name}:\t\t\t!problems!')
# Out:
# Allegany:			found
# Arthur Kill ST 2:			found
# Arthur Kill ST 3:			found
# Astoria 2:			found
# Astoria 3:			has multiple entries
# Astoria 5:			has multiple entries
# Astoria CC 1:			found
# Astoria CC 2:			found
# Astoria East Energy - CC1:			found
# Astoria East Energy - CC2:			found
# Astoria Energy 2 - CC3:			found
# Astoria Energy 2 - CC4:			found
# Astoria GT 2-1:			has multiple entries
# Astoria GT 2-2:			has multiple entries
# Astoria GT 2-3:			has multiple entries
# Astoria GT 2-4:			has multiple entries
# Astoria GT 3-1:			has multiple entries
# Astoria GT 3-2:			has multiple entries
# Astoria GT 3-3:			has multiple entries
# Astoria GT 3-4:			has multiple entries
# Astoria GT 4-1:			has multiple entries
# Astoria GT 4-2:			has multiple entries
# Astoria GT 4-3:			has multiple entries
# Astoria GT 4-4:			has multiple entries
# Athens 1:			found
# Athens 2:			found
# Athens 3:			found
# Barrett 03:			found
# Barrett 04:			found
# Barrett 05:			found
# Barrett 06:			found
# Barrett 08:			found
# Barrett GT 01:			found
# Barrett GT 02:			found
# Barrett ST 01:			found
# Barrett ST 02:			found
# Batavia:			found
# Beaver Falls:			found
# Bethlehem Energy Center:			has multiple entries
# Bethpage:			has multiple entries
# Bethpage 3:			found
# Bethpage GT4:			found
# Bowline 1:			found
# Bowline 2:			found
# Brentwood:			found
# Brooklyn Navy Yard:			has multiple entries
# CPV_VALLEY___CC1:			found
# CPV_VALLEY___CC2:			found
# Caithness_CC_1:			found
# Carr St.-E. Syr:			has multiple entries
# Carthage Energy:			found
# Castleton Energy Center:			found
# Cayuga 1:			found
# Danskammer 1:			found
# Danskammer 2:			found
# Danskammer 3:			found
# Danskammer 4:			found
# EMPIRE_CC_1:			found
# EMPIRE_CC_2:			found
# East River 1:			found
# East River 2:			found
# Far Rockaway GT1:			found
# Far Rockaway GT2:			found
# Flynn:			found
# Fortistar - N.Tonawanda:			found
# Freeport CT 1:			found
# Freeport CT 2:			found
# Glenwood GT 02:			found
# Glenwood GT 03:			found
# Glenwood GT 04:			found
# Glenwood GT 05:			found
# Gowanus 5:			found
# Gowanus 6:			found
# Greenidge 4:			found
# Greenport GT1:			found
# Harlem River 1:			found
# Harlem River 2:			found
# Hellgate 1:			found
# Hellgate 2:			found
# Hillburn GT:			found
# Holtsville 01:			found
# Holtsville 02:			found
# Holtsville 03:			found
# Holtsville 04:			found
# Holtsville 05:			found
# Holtsville 06:			found
# Holtsville 07:			found
# Holtsville 08:			found
# Holtsville 09:			found
# Holtsville 10:			found
# Indeck-Corinth:			found
# Indeck-Olean:			found
# Indeck-Oswego:			found
# Indeck-Silver Springs:			found
# Indeck-Yerkes:			found
# Independence:			has multiple entries
# Jamestown 7:			found
# KIAC_JFK_GT1:			found
# KIAC_JFK_GT2:			found
# Kent:			found
# Lockport:			has multiple entries
# Massena:			found
# Nassau Energy Corporation:			found
# Northport 1:			found
# Northport 2:			found
# Northport 3:			found
# Northport 4:			found
# Oswego 5:			found
# Oswego 6:			found
# Pilgrim GT1:			found
# Pilgrim GT2:			found
# Pinelawn Power 1:			found
# Port Jefferson 3:			found
# Port Jefferson 4:			found
# Port Jefferson GT 02:			found
# Port Jefferson GT 03:			found
# Pouch:			found
# Ravenswood CC 04:			found
# Ravenswood ST 01:			found
# Ravenswood ST 02:			found
# Ravenswood ST 03:			found
# Rensselaer:			found
# Roseton 1:			found
# Roseton 2:			found
# Saranac Energy:			has multiple entries
# Selkirk-I:			found
# Selkirk-II:			has multiple entries
# Shoemaker GT:			found
# Shoreham GT3:			missing
# Shoreham GT4:			missing
# Somerset:			found
# Sterling:			found
# Stony Brook   (BTM:NG):			found
# Syracuse:			found
# Vernon Blvd 2:			found
# Vernon Blvd 3:			found
# Wading River 1:			found
# Wading River 2:			found
# Wading River 3:			found
# West Babylon 4:			found
# 59 St.  GT 1:			missing
# 74 St.  GT 1:			missing
# 74 St.  GT 2:			missing
# Allied Frozen Storage:			missing
# Arthur Kill Cogen:			missing
# Arthur Kill GT 1:			missing
# Astoria GT 01:			missing
# Barrett 09:			found
# Barrett 10:			found
# Barrett 11:			found
# Barrett 12:			found
# Binghamton (RET - 1/9/18):			missing
# Burrstone Engy Center, LLC LU:			missing
# Burrstone Engy Center, LLC U:			missing
# Charles P Keller 09:			missing
# Charles P Keller 10:			missing
# Charles P Keller 11:			missing
# Charles P Keller 14:			missing
# Coxsackie GT:			missing
# East Hampton 2:			missing
# East Hampton 3:			missing
# East Hampton 4:			missing
# East Hampton GT 01:			missing
# Freeport 1-4:			missing
# Freeport 2-3:			missing
# General Mills Inc:			missing
# Gowanus 1-1:			found
# Gowanus 1-2:			found
# Gowanus 1-3:			found
# Gowanus 1-4:			found
# Gowanus 1-5:			found
# Gowanus 1-6:			found
# Gowanus 1-7:			found
# Gowanus 2-1:			found
# Gowanus 2-2:			found
# Gowanus 2-3:			found
# Gowanus 2-4:			found
# Gowanus 2-5:			found
# Gowanus 2-6:			found
# Gowanus 2-7:			found
# Gowanus 2-8:			found
# Gowanus 3-1:			found
# Gowanus 3-2:			found
# Gowanus 3-3:			found
# Gowanus 3-4:			found
# Gowanus 3-5:			found
# Gowanus 3-6:			found
# Gowanus 3-7:			found
# Gowanus 3-8:			found
# Gowanus 4-1:			found
# Gowanus 4-2:			found
# Gowanus 4-3:			found
# Gowanus 4-4:			found
# Gowanus 4-5:			found
# Gowanus 4-6:			found
# Gowanus 4-8:			found
# Hudson Ave 3:			found
# Hudson Ave 4:			found
# Hudson Ave 5:			found
# Jamestown 5:			found
# Jamestown 6:			found
# Narrows 1-1:			found
# Narrows 1-2:			found
# Narrows 1-3:			found
# Narrows 1-4:			found
# Narrows 1-5:			found
# Narrows 1-6:			found
# Narrows 1-7:			found
# Narrows 1-8:			found
# Narrows 2-1:			found
# Narrows 2-2:			found
# Narrows 2-3:			found
# Narrows 2-4:			found
# Narrows 2-5:			found
# Narrows 2-6:			found
# Narrows 2-7:			found
# Narrows 2-8:			found
# Northport GT:			missing
# Ravenswood 01:			missing
# Ravenswood 10:			missing
# Ravenswood 11:			missing
# S Hampton 1:			missing
# Shoreham 1:			found
# Shoreham 2:			found
# South Cairo:			missing
# Southold 1:			missing
# St. Elizabeth Medical Center:			missing

# %%
# Read in data from the NY Simple Net
ed_gen = pd.read_csv('../ny_emis/ed_output/thermal_with_renewable_20160805_20160815.csv', parse_dates=['TimeStamp'], infer_datetime_format=True)
ed_gen = ed_gen.set_index('TimeStamp')

# %%
# Drop unnecessary units from the lookup df
gen_df = lu_df[lu_df['NYISO Name'].isin(ed_gen.columns)].reset_index(drop=True)
# Format the final dataset
gen_df = pd.concat([gen_df, pd.DataFrame(index=gen_df.index, columns=ed_gen.index.values)], axis=1)

# %%
# Create a generation dataframe for each ORISPL, UNIT ID combination
for name in gen_df['NYISO Name']:
    # Get simple net generation 
    unit_gen = ed_gen[name]
    # Determine how many units are associated with this name
    unit_bool = gen_df['NYISO Name'] == name
    n_units = sum(unit_bool)
    # Edit the simple net generation based on this number of units
    unit_gen = unit_gen / n_units
    # Fill this unit gen profile into all matching units
    for idx in unit_bool[unit_bool].index.values:
        gen_df.loc[idx, unit_gen.index] = unit_gen

# %%
gen_df
# Out:
#            RGGI Facility Name  ORISPL Unit ID        NYISO Name   PTID  \
# 0                 23rd & 3rd     7910    2301         Gowanus 5  24156
# 1                 23rd & 3rd     7910    2302         Gowanus 6  24157
# 2    Allegany Station No. 133   10619       1          Allegany  23514
# 3                 Arthur Kill    2490      20  Arthur Kill ST 2  23512
# 4                 Arthur Kill    2490      30  Arthur Kill ST 3  23513
# ..                        ...     ...     ...               ...    ...
# 216          Vernon Boulevard    7909    VB02     Vernon Blvd 3  24163
# 217     Wading River Facility    7146  UGT007    Wading River 1  23522
# 218     Wading River Facility    7146  UGT008    Wading River 2  23547
# 219     Wading River Facility    7146  UGT009    Wading River 3  23601
# 220     West Babylon Facility    2521  UGT001    West Babylon 4  23714
#
#     2016-08-05 00:00:00 2016-08-05 01:00:00 2016-08-05 02:00:00  \
# 0                  19.0                19.0                19.0
# 1                   6.0                 6.0                 6.0
# 2                  11.0                11.0                11.0
# 3                  96.0                96.0                96.0
# 4                   1.0                 1.0                 1.0
# ..                  ...                 ...                 ...
# 216                15.0                15.0                15.0
# 217                 9.0                 9.0                 9.0
# 218                 7.8                 7.8                 7.8
# 219                 4.0                 4.0                 4.0
# 220                 3.0                 3.0                 3.0
#
#     2016-08-05 03:00:00 2016-08-05 04:00:00  ... 2016-08-15 14:00:00  \
# 0                  19.0                19.0  ...                44.0
# 1                   6.0                 6.0  ...                43.0
# 2                  11.0                11.0  ...                66.0
# 3                  96.0                96.0  ...               349.0
# 4                   1.0                 1.0  ...               539.0
# ..                  ...                 ...  ...                 ...
# 216                15.0                15.0  ...                42.0
# 217                 9.0                 9.0  ...                 9.0
# 218                 7.8                 7.8  ...                 7.8
# 219                 4.0                 4.0  ...                 4.0
# 220                 3.0                 3.0  ...                 3.0
#
#     2016-08-15 15:00:00 2016-08-15 16:00:00 2016-08-15 17:00:00  \
# 0                  19.0                19.0                19.0
# 1                  43.0                 6.0                 6.0
# 2                  66.0                66.0                66.0
# 3                 349.0               349.0               349.0
# 4                 539.0               539.0               539.0
# ..                  ...                 ...                 ...
# 216                15.0                15.0                15.0
# 217                 9.0                 9.0                 9.0
# 218                 7.8                 7.8                 7.8
# 219                 4.0                 4.0                 4.0
# 220                 3.0                 3.0                 3.0
#
#     2016-08-15 18:00:00 2016-08-15 19:00:00 2016-08-15 20:00:00  \
# 0                  19.0                19.0                19.0
# 1                   6.0                 6.0                 6.0
# 2                  66.0                66.0                66.0
# 3                 349.0               349.0               349.0
# 4                 539.0               539.0               539.0
# ..                  ...                 ...                 ...
# 216                15.0                15.0                15.0
# 217                 9.0                 9.0                 9.0
# 218                 7.8                 7.8                 7.8
# 219                 4.0                 4.0                 4.0
# 220                 3.0                 3.0                 3.0
#
#     2016-08-15 21:00:00 2016-08-15 22:00:00 2016-08-15 23:00:00
# 0                  19.0                19.0                19.0
# 1                   6.0                 6.0                 6.0
# 2                  66.0                66.0                66.0
# 3                 349.0               349.0               349.0
# 4                   1.0               539.0               539.0
# ..                  ...                 ...                 ...
# 216                15.0                15.0                15.0
# 217                 9.0                 9.0                 9.0
# 218                 7.8                 7.8                 7.8
# 219                 4.0                 4.0                 4.0
# 220                 3.0                 3.0                 3.0
#
# [221 rows x 269 columns]

# %%
for ii, name in enumerate(ed_gen.index):
    # Get the ORISPL from the Lookup df
    match = (lu_df['NYISO Name'] == name)
    orispl = lu_df['ORISPL'][match]
    if len(orispl.unique()) > 1:
        print(f'Warning: found {len(orispl.unique())} ORISPLs for {name}')
  
    # Get the Unit ID from the Lookup df & add additional rows if necessary
    unitid = lu_df['Unit ID'][match]
    if len(unitid.unique()) > 1:
        print(f'Warning: found {len(unitid.unique())} UNIT IDs for {name}')
# Out:
# Warning: found 2 UNIT IDs for Astoria 3
# Warning: found 2 UNIT IDs for Astoria 5
# Warning: found 2 UNIT IDs for Astoria GT 2-1
# Warning: found 2 UNIT IDs for Astoria GT 2-2
# Warning: found 2 UNIT IDs for Astoria GT 2-3
# Warning: found 2 UNIT IDs for Astoria GT 2-4
# Warning: found 2 UNIT IDs for Astoria GT 3-1
# Warning: found 2 UNIT IDs for Astoria GT 3-2
# Warning: found 2 UNIT IDs for Astoria GT 3-3
# Warning: found 2 UNIT IDs for Astoria GT 3-4
# Warning: found 2 UNIT IDs for Astoria GT 4-1
# Warning: found 2 UNIT IDs for Astoria GT 4-2
# Warning: found 2 UNIT IDs for Astoria GT 4-3
# Warning: found 2 UNIT IDs for Astoria GT 4-4
# Warning: found 3 UNIT IDs for Bethlehem Energy Center
# Warning: found 2 UNIT IDs for Bethpage
# Warning: found 2 UNIT IDs for Brooklyn Navy Yard
# Warning: found 2 UNIT IDs for Carr St.-E. Syr
# Warning: found 4 UNIT IDs for Independence
# Warning: found 3 UNIT IDs for Lockport
# Warning: found 2 UNIT IDs for Saranac Energy
# Warning: found 2 UNIT IDs for Selkirk-II

# %%
# Read in the generator data previously preprocessed by ERTAC EGU tool
base_df = pd.read_csv('../CONUS2016/inputs/camd_hourly_base.csv', low_memory=False)

# %%
base_df.head()
# Out:
#   STATE FACILITY_NAME ORISPL_CODE UNITID     OP_DATE  OP_HOUR  OP_TIME  GLOAD  \
# 0    AL         Barry           3      1  01-01-2016     14.0      0.0    NaN
# 1    AL         Barry           3      1  01-01-2016     15.0      0.0    NaN
# 2    AL         Barry           3      1  01-01-2016     16.0      0.0    NaN
# 3    AL         Barry           3      1  01-01-2016     17.0      0.0    NaN
# 4    AL         Barry           3      1  01-01-2016     18.0      0.0    NaN
#
#    SLOAD  SO2_MASS  ... NOX_RATE_MEASURE_FLG  NOX_MASS NOX_MASS_MEASURE_FLG  \
# 0    NaN       NaN  ...                  NaN       NaN                  NaN
# 1    NaN       NaN  ...                  NaN       NaN                  NaN
# 2    NaN       NaN  ...                  NaN       NaN                  NaN
# 3    NaN       NaN  ...                  NaN       NaN                  NaN
# 4    NaN       NaN  ...                  NaN       NaN                  NaN
#
#    CO2_MASS CO2_MASS_MEASURE_FLG  CO2_RATE CO2_RATE_MEASURE_FLG  HEAT_INPUT  \
# 0       NaN                  NaN       NaN                  NaN         NaN
# 1       NaN                  NaN       NaN                  NaN         NaN
# 2       NaN                  NaN       NaN                  NaN         NaN
# 3       NaN                  NaN       NaN                  NaN         NaN
# 4       NaN                  NaN       NaN                  NaN         NaN
#
#   FAC_ID  UNIT_ID
# 0    1.0      1.0
# 1    1.0      1.0
# 2    1.0      1.0
# 3    1.0      1.0
# 4    1.0      1.0
#
# [5 rows x 24 columns]

# %%
base_df = base_df[base_df['STATE'] == 'NY']

# %%
base_df['FACILITY_NAME'].unique()
# Out:
# array(['Danskammer Generating Station', 'Arthur Kill', 'East River',
#        'Gowanus Generating Station', 'Hudson Avenue',
#        'Narrows Generating Station', 'Ravenswood Generating Station',
#        'Ravenswood Steam Plant', '59th Street', '74th Street',
#        'E F Barrett', 'East Hampton Facility', 'Glenwood', 'Northport',
#        'Port Jefferson Energy Center', 'West Babylon Facility',
#        'Greenidge Generation LLC', 'Cayuga Operating Company, LLC',
#        'Bethlehem Energy Center (Albany)', 'Huntley Power',
#        'NRG Dunkirk Power', 'Oswego Harbor Power',
#        'Bowline Generating Station', 'Hillburn', 'Shoemaker',
#        'S A Carlson', 'Somerset Operating Company  (Kintigh)',
#        'Wading River Facility', 'Richard M Flynn (Holtsville)',
#        'Glenwood Landing Energy Center', 'Roseton Generating LLC',
#        'Holtsville Facility', 'Astoria Generating Station',
#        'Astoria Gas Turbine Power',
#        'RED-Rochester, LLC-Eastman Business Park', 'Castleton Power, LLC',
#        'Black River Generation, LLC', 'Beaver Falls, LLC',
#        'Allegany Station No. 133', 'Carthage Energy', 'Syracuse, LLC',
#        'Selkirk Cogen Partners', 'AG - Energy', 'Bethpage Energy Center',
#        'Indeck-Silver Springs Energy Center',
#        'Indeck-Oswego Energy Center', 'Indeck-Yerkes Energy Center',
#        'Indeck-Corinth Energy Center', 'Covanta Niagara',
#        'Sterling Power Plant', 'Carr Street Generating Station',
#        'Nassau Energy Corporation', 'Rensselaer Cogen', 'Lockport',
#        'Indeck-Olean Energy Center', 'Ticonderoga Mill',
#        'KIAC Cogeneration', 'Fortistar North Tonawanda Inc',
#        'Nissequogue Energy Center', 'Independence',
#        'Saranac Power Partners, LP', 'Massena Energy Facility',
#        'Batavia Energy', 'Brooklyn Navy Yard Cogeneration',
#        'Astoria Energy', 'Momentive Performance Materials',
#        'Vernon Boulevard', '23rd and 3rd', 'Pouch Terminal', 'Brentwood',
#        'Hell Gate', 'Harlem River Yard', 'North 1st',
#        'Athens Generating Company', 'Bayswater Peaking Facility',
#        'Lafarge Building Materials, Inc.', 'Binghamton Cogen Plant',
#        'Edgewood Energy', 'Shoreham Energy', 'Freeport Power Plant No. 2',
#        'Lehigh Northeast Cement Company', 'Hawkeye Energy Greenport, LLC',
#        'Equus  Power I', 'Caithness Long Island Energy Center',
#        'Pinelawn Power', 'Empire Generating Company LLC',
#        'Riverbay Corp. - Co-Op City', 'Poletti 500 MW CC',
#        'Cornell University Ithaca Campus'], dtype=object)

# %%
base_df[base_df['FACILITY_NAME'] == 'Ravenswood Steam Plant'][base_df['OP_DATE'] == '04-01-2016']['UNITID'].unique()
# Out:
# <ipython-input-11-84fa3aaa7047>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   base_df[base_df['FACILITY_NAME'] == 'Ravenswood Steam Plant'][base_df['OP_DATE'] == '04-01-2016']['UNITID'].unique()
# array(['BLR001', 'BLR002', 'BLR003', 'BLR004'], dtype=object)
